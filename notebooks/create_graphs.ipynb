# %%
import os
working_dir_path = %pwd  #look at the current work dir
if os.path.basename(working_dir_path) == 'notebooks':
    # %cd ..
# %pwd
# Out:
# c:\Users\joelw\OneDrive\Documents\Projects\Programming\Self-Arranging-Networks
# 'c:\\Users\\joelw\\OneDrive\\Documents\\Projects\\Programming\\Self-Arranging-Networks'

# %%
import torch
import networkx as nx
import numpy as np
import plotly.graph_objects as go
import plotly
import src.network_arranger as na
import src.utils as utils

# %%
x = [(i+1)/50 for i in range(1,1000 )]
y = [1/x_**2+x_**2-2 for x_ in x]
z = [1/x_**2+np.log(x_**2)-1 for x_ in x]
fig = go.Figure(
    data=[
        go.Scatter(x=x, y=y,
                    mode="lines",
                    name="Connected",
                    line=dict(color="#FE5F55", width=2)
        ), 
    ],
    layout=go.Layout(width=1000, height=300,
        xaxis=dict(range=[0.01, 6], autorange=False),
        yaxis=dict(range=[-1, 30], autorange=False))
)
fig.show()

# %%
x = [(i+1)/50 for i in range(1,1000 )]
y = [1/x_**2+x_**2-2 for x_ in x]
z = [1/x_**2+np.log(x_**2)-1 for x_ in x]
fig = go.Figure(
    data=[
        go.Scatter(x=x, y=z,
                    mode="lines",
                    name="General",
                    line=dict(color="#FE5F55", width=2)
        ), 
    ],
    layout=go.Layout(width=1000, height=300,
        xaxis=dict(range=[0.01, 6], autorange=False),
        yaxis=dict(range=[-1, 5], autorange=False))
)
fig.show()
